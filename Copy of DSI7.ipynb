# %%
imovel = input("digite o tipo de imovel")
consumo_mensal_metros3 = float (input("digite o consumo_mensal"))
if   ("apartamento") and ("consumo") < 10:
  print("consumo economico - excelente controle de agua")
elif  ("casa") < 25:
   print("consumo moderado - dentro do padrao residencial")
elif  ("apartamento") + ("casa") == 25:
   print("consumo moderado - dentro do padrao residencial")
else:
   print("consumo excessivo - adote medidas de economia e verifique vazamentos")

   ##  aqui faco a etapa de integracao com o match case para o programa

match imovel:
     case "comercial":
        print ("tarifa comercial  aplicada - consulte plano corporativo")
     case "apartamento com consumo menor que 10 ":
        print ("consumo economico - excelente controle de agua")
     case "apartamento | casa com consumo menor que 25 ":
        print ("consumo moderado - dentro do padrão residencial")
     case _:
        print ("consumo excessivo - adote medidas de economia e verifique vazamentos")
# Out:
# digite o tipo de imovel  casa
# digite o consumo_mensal  26
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4641/571676293.py in <cell line: 0>()
#       1 imovel = input("digite o tipo de imovel")
#       2 consumo_mensal_metros3 = float (input("digite o consumo_mensal"))
# ----> 3 if   ("apartamento") and ("consumo") < 10:
#       4    print("consumo economico - excelente controle de agua")
#       5 elif  ("casa") < 25:
#
# TypeError: '<' not supported between instances of 'str' and 'int'
